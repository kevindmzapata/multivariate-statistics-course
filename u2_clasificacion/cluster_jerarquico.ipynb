# %%
# Librerias para cluster gerarquico
from scipy.cluster.hierarchy import dendrogram, linkage
from matplotlib import pyplot as plt
from sklearn.datasets import make_blobs
import numpy as np

# %%
X, y = make_blobs(n_samples=30, centers=3, n_features=2, cluster_std=0.7, random_state=0)

plt.scatter(X[:,0], X[:,1], c=y)
plt.show()

# %%
# Calculo coeficiente de correlacion cofenetico
from scipy.cluster.hierarchy import cophenet
from scipy.spatial.distance import pdist

Z1 = linkage(X, method="ward")
c, coph_dists = cophenet(Z, pdist(X))
print(c)
# Out:
# 0.8533509461169554

# %%
dendrogram(Z1)
plt.show()

# %%
Z2 = linkage(X, method="single")
c, coph_dists = cophenet(Z, pdist(X))
print(c)
# Out:
# 0.8533509461169554

# %%
dendrogram(Z2)
plt.show()

# %%
# Generar clusters de Z1 en 3 grupos
from scipy.cluster.hierarchy import fcluster

clusters = fcluster(Z1, t=5, criterion="distance")
print(clusters)
# Out:
# [1 1 1 1 3 2 3 1 3 1 1 1 1 3 2 2 3 2 1 2 3 3 2 2 2 3 3 3 1 2]

# %%
plt.scatter(X[:,0], X[:,1], c=clusters)
plt.show()
